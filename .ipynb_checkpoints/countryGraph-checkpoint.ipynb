# %%
# !pip install networkx

# %%
import networkx as nx
G = nx.Graph()

# %%
import json

nameToCCA3 = {}
CCA3toName = {}

#Build CCA3 maps & add nodes
with open('countries.json') as json_file:  
    data = json.load(json_file)
    for p in data:
        nameToCCA3[p['name']['common']] = p['cca3']
        CCA3toName[p['cca3']] = p['name']['common']
        print(p['name']['common'])
        G.add_node(p['name']['common'])
# Out:
# Aruba
# Afghanistan
# Angola
# Anguilla
# Åland Islands
# Albania
# Andorra
# United Arab Emirates
# Argentina
# Armenia
# American Samoa
# Antarctica
# French Southern and Antarctic Lands
# Antigua and Barbuda
# Australia
# Austria
# Azerbaijan
# Burundi
# Belgium
# Benin
# Burkina Faso
# Bangladesh
# Bulgaria
# Bahrain
# Bahamas
# Bosnia and Herzegovina
# Saint Barthélemy
# Saint Helena, Ascension and Tristan da Cunha
# Belarus
# Belize
# Bermuda
# Bolivia
# Caribbean Netherlands
# Brazil
# Barbados
# Brunei
# Bhutan
# Bouvet Island
# Botswana
# Central African Republic
# Canada
# Cocos (Keeling) Islands
# Switzerland
# Chile
# China
# Ivory Coast
# Cameroon
# DR Congo
# Republic of the Congo
# Cook Islands
# Colombia
# Comoros
# Cape Verde
# Costa Rica
# Cuba
# Curaçao
# Christmas Island
# Cayman Islands
# Cyprus
# Czechia
# Germany
# Djibouti
# Dominica
# Denmark
# Dominican Republic
# Algeria
# Ecuador
# Egypt
# Eritrea
# Western Sahara
# Spain
# Estonia
# Ethiopia
# Finland
# Fiji
# Falkland Islands
# France
# Faroe Islands
# Micronesia
# Gabon
# United Kingdom
# Georgia
# Guernsey
# Ghana
# Gibraltar
# Guinea
# Guadeloupe
# Gambia
# Guinea-Bissau
# Equatorial Guinea
# Greece
# Grenada
# Greenland
# Guatemala
# French Guiana
# Guam
# Guyana
# Hong Kong
# Heard Island and McDonald Islands
# Honduras
# Croatia
# Haiti
# Hungary
# Indonesia
# Isle of Man
# India
# British Indian Ocean Territory
# Ireland
# Iran
# Iraq
# Iceland
# Israel
# Italy
# Jamaica
# Jersey
# Jordan
# Japan
# Kazakhstan
# Kenya
# Kyrgyzstan
# Cambodia
# Kiribati
# Saint Kitts and Nevis
# South Korea
# Kosovo
# Kuwait
# Laos
# Lebanon
# Liberia
# Libya
# Saint Lucia
# Liechtenstein
# Sri Lanka
# Lesotho
# Lithuania
# Luxembourg
# Latvia
# Macau
# Saint Martin
# Morocco
# Monaco
# Moldova
# Madagascar
# Maldives
# Mexico
# Marshall Islands
# North Macedonia
# Mali
# Malta
# Myanmar
# Montenegro
# Mongolia
# Northern Mariana Islands
# Mozambique
# Mauritania
# Montserrat
# Martinique
# Mauritius
# Malawi
# Malaysia
# Mayotte
# Namibia
# New Caledonia
# Niger
# Norfolk Island
# Nigeria
# Nicaragua
# Niue
# Netherlands
# Norway
# Nepal
# Nauru
# New Zealand
# Oman
# Pakistan
# Panama
# Pitcairn Islands
# Peru
# Philippines
# Palau
# Papua New Guinea
# Poland
# Puerto Rico
# North Korea
# Portugal
# Paraguay
# Palestine
# French Polynesia
# Qatar
# Réunion
# Romania
# Russia
# Rwanda
# Saudi Arabia
# Sudan
# Senegal
# Singapore
# South Georgia
# Svalbard and Jan Mayen
# Solomon Islands
# Sierra Leone
# El Salvador
# San Marino
# Somalia
# Saint Pierre and Miquelon
# Serbia
# South Sudan
# São Tomé and Príncipe
# Suriname
# Slovakia
# Slovenia
# Sweden
# Eswatini
# Sint Maarten
# Seychelles
# Syria
# Turks and Caicos Islands
# Chad
# Togo
# Thailand
# Tajikistan
# Tokelau
# Turkmenistan
# Timor-Leste
# Tonga
# Trinidad and Tobago
# Tunisia
# Turkey
# Tuvalu
# Taiwan
# Tanzania
# Uganda
# Ukraine
# United States Minor Outlying Islands
# Uruguay
# United States
# Uzbekistan
# Vatican City
# Saint Vincent and the Grenadines
# Venezuela
# British Virgin Islands
# United States Virgin Islands
# Vietnam
# Vanuatu
# Wallis and Futuna
# Samoa
# Yemen
# South Africa
# Zambia
# Zimbabwe

# %%
CCA3toName

# %%
with open('countries.json') as json_file:  
    data = json.load(json_file)
    for p in data:
        print('Borders: ')
        print(p['borders'])
        source = p['cca3']
        for dest in p['borders']:
            #print("FROM: " + CCA3toName[p['cca3']] + " TO: " + CCA3toName[dest])
            #print (dest)
            #print("FROM: " + CCA3toName[p['cca3']] + " TO: " + CCA3toName[dest])
            G.add_edge(CCA3toName[p['cca3']], CCA3toName[dest])
        #G.add_node(p['cca3'])
# Out:
# Borders:
# []
# Borders:
# ['IRN', 'PAK', 'TKM', 'UZB', 'TJK', 'CHN']
# Borders:
# ['COG', 'COD', 'ZMB', 'NAM']
# Borders:
# []
# Borders:
# []
# Borders:
# ['MNE', 'GRC', 'MKD', 'UNK']
# Borders:
# ['FRA', 'ESP']
# Borders:
# ['OMN', 'SAU']
# Borders:
# ['BOL', 'BRA', 'CHL', 'PRY', 'URY']
# Borders:
# ['AZE', 'GEO', 'IRN', 'TUR']
# Borders:
# []
# Borders:
# []
# Borders:
# []
# Borders:
# []
# Borders:
# []
# Borders:
# ['CZE', 'DEU', 'HUN', 'ITA', 'LIE', 'SVK', 'SVN', 'CHE']
# Borders:
# ['ARM', 'GEO', 'IRN', 'RUS', 'TUR']
# Borders:
# ['COD', 'RWA', 'TZA']
# Borders:
# ['FRA', 'DEU', 'LUX', 'NLD']
# Borders:
# ['BFA', 'NER', 'NGA', 'TGO']
# Borders:
# ['BEN', 'CIV', 'GHA', 'MLI', 'NER', 'TGO']
# Borders:
# ['MMR', 'IND']
# Borders:
# ['GRC', 'MKD', 'ROU', 'SRB', 'TUR']
# Borders:
# []
# Borders:
# []
# Borders:
# ['HRV', 'MNE', 'SRB']
# Borders:
# []
# Borders:
# []
# Borders:
# ['LVA', 'LTU', 'POL', 'RUS', 'UKR']
# Borders:
# ['GTM', 'MEX']
# Borders:
# []
# Borders:
# ['ARG', 'BRA', 'CHL', 'PRY', 'PER']
# Borders:
# []
# Borders:
# ['ARG', 'BOL', 'COL', 'GUF', 'GUY', 'PRY', 'PER', 'SUR', 'URY', 'VEN']
# Borders:
# []
# Borders:
# ['MYS']
# Borders:
# ['CHN', 'IND']
# Borders:
# []
# Borders:
# ['NAM', 'ZAF', 'ZMB', 'ZWE']
# Borders:
# ['CMR', 'TCD', 'COD', 'COG', 'SSD', 'SDN']
# Borders:
# ['USA']
# Borders:
# []
# Borders:
# ['AUT', 'FRA', 'ITA', 'LIE', 'DEU']
# Borders:
# ['ARG', 'BOL', 'PER']
# Borders:
# ['AFG', 'BTN', 'MMR', 'HKG', 'IND', 'KAZ', 'NPL', 'PRK', 'KGZ', 'LAO', 'MAC', 'MNG', 'PAK', 'RUS', 'TJK', 'VNM']
# Borders:
# ['BFA', 'GHA', 'GIN', 'LBR', 'MLI']
# Borders:
# ['CAF', 'TCD', 'COG', 'GNQ', 'GAB', 'NGA']
# Borders:
# ['AGO', 'BDI', 'CAF', 'COG', 'RWA', 'SSD', 'TZA', 'UGA', 'ZMB']
# Borders:
# ['AGO', 'CMR', 'CAF', 'COD', 'GAB']
# Borders:
# []
# Borders:
# ['BRA', 'ECU', 'PAN', 'PER', 'VEN']
# Borders:
# []
# Borders:
# []
# Borders:
# ['NIC', 'PAN']
# Borders:
# []
# Borders:
# []
# Borders:
# []
# Borders:
# []
# Borders:
# []
# Borders:
# ['AUT', 'DEU', 'POL', 'SVK']
# Borders:
# ['AUT', 'BEL', 'CZE', 'DNK', 'FRA', 'LUX', 'NLD', 'POL', 'CHE']
# Borders:
# ['ERI', 'ETH', 'SOM']
# Borders:
# []
# Borders:
# ['DEU']
# Borders:
# ['HTI']
# Borders:
# ['TUN', 'LBY', 'NER', 'ESH', 'MRT', 'MLI', 'MAR']
# Borders:
# ['COL', 'PER']
# Borders:
# ['ISR', 'LBY', 'PSE', 'SDN']
# Borders:
# ['DJI', 'ETH', 'SDN']
# Borders:
# ['DZA', 'MRT', 'MAR']
# Borders:
# ['AND', 'FRA', 'GIB', 'PRT', 'MAR']
# Borders:
# ['LVA', 'RUS']
# Borders:
# ['DJI', 'ERI', 'KEN', 'SOM', 'SSD', 'SDN']
# Borders:
# ['NOR', 'SWE', 'RUS']
# Borders:
# []
# Borders:
# []
# Borders:
# ['AND', 'BEL', 'DEU', 'ITA', 'LUX', 'MCO', 'ESP', 'CHE']
# Borders:
# []
# Borders:
# []
# Borders:
# ['CMR', 'COG', 'GNQ']
# Borders:
# ['IRL']
# Borders:
# ['ARM', 'AZE', 'RUS', 'TUR']
# Borders:
# []
# Borders:
# ['BFA', 'CIV', 'TGO']
# Borders:
# ['ESP']
# Borders:
# ['CIV', 'GNB', 'LBR', 'MLI', 'SEN', 'SLE']
# Borders:
# []
# Borders:
# ['SEN']
# Borders:
# ['GIN', 'SEN']
# Borders:
# ['CMR', 'GAB']
# Borders:
# ['ALB', 'BGR', 'TUR', 'MKD']
# Borders:
# []
# Borders:
# []
# Borders:
# ['BLZ', 'SLV', 'HND', 'MEX']
# Borders:
# ['BRA', 'SUR']
# Borders:
# []
# Borders:
# ['BRA', 'SUR', 'VEN']
# Borders:
# ['CHN']
# Borders:
# []
# Borders:
# ['GTM', 'SLV', 'NIC']
# Borders:
# ['BIH', 'HUN', 'MNE', 'SRB', 'SVN']
# Borders:
# ['DOM']
# Borders:
# ['AUT', 'HRV', 'ROU', 'SRB', 'SVK', 'SVN', 'UKR']
# Borders:
# ['TLS', 'MYS', 'PNG']
# Borders:
# []
# Borders:
# ['BGD', 'BTN', 'MMR', 'CHN', 'NPL', 'PAK']
# Borders:
# []
# Borders:
# ['GBR']
# Borders:
# ['AFG', 'ARM', 'AZE', 'IRQ', 'PAK', 'TUR', 'TKM']
# Borders:
# ['IRN', 'JOR', 'KWT', 'SAU', 'SYR', 'TUR']
# Borders:
# []
# Borders:
# ['EGY', 'JOR', 'LBN', 'PSE', 'SYR']
# Borders:
# ['AUT', 'FRA', 'SMR', 'SVN', 'CHE', 'VAT']
# Borders:
# []
# Borders:
# []
# Borders:
# ['IRQ', 'ISR', 'PSE', 'SAU', 'SYR']
# Borders:
# []
# Borders:
# ['CHN', 'KGZ', 'RUS', 'TKM', 'UZB']
# Borders:
# ['ETH', 'SOM', 'SSD', 'TZA', 'UGA']
# Borders:
# ['CHN', 'KAZ', 'TJK', 'UZB']
# Borders:
# ['LAO', 'THA', 'VNM']
# Borders:
# []
# Borders:
# []
# Borders:
# ['PRK']
# Borders:
# ['ALB', 'MKD', 'MNE', 'SRB']
# Borders:
# ['IRQ', 'SAU']
# Borders:
# ['MMR', 'KHM', 'CHN', 'THA', 'VNM']
# Borders:
# ['ISR', 'SYR']
# Borders:
# ['GIN', 'CIV', 'SLE']
# Borders:
# ['DZA', 'TCD', 'EGY', 'NER', 'SDN', 'TUN']
# Borders:
# []
# Borders:
# ['AUT', 'CHE']
# Borders:
# ['IND']
# Borders:
# ['ZAF']
# Borders:
# ['BLR', 'LVA', 'POL', 'RUS']
# Borders:
# ['BEL', 'FRA', 'DEU']
# Borders:
# ['BLR', 'EST', 'LTU', 'RUS']
# Borders:
# ['CHN']
# Borders:
# ['SXM']
# Borders:
# ['DZA', 'ESH', 'ESP']
# Borders:
# ['FRA']
# Borders:
# ['ROU', 'UKR']
# Borders:
# []
# Borders:
# []
# Borders:
# ['BLZ', 'GTM', 'USA']
# Borders:
# []
# Borders:
# ['ALB', 'BGR', 'GRC', 'UNK', 'SRB']
# Borders:
# ['DZA', 'BFA', 'GIN', 'CIV', 'MRT', 'NER', 'SEN']
# Borders:
# []
# Borders:
# ['BGD', 'CHN', 'IND', 'LAO', 'THA']
# Borders:
# ['ALB', 'BIH', 'HRV', 'UNK', 'SRB']
# Borders:
# ['CHN', 'RUS']
# Borders:
# []
# Borders:
# ['MWI', 'ZAF', 'SWZ', 'TZA', 'ZMB', 'ZWE']
# Borders:
# ['DZA', 'MLI', 'SEN', 'ESH']
# Borders:
# []
# Borders:
# []
# Borders:
# []
# Borders:
# ['MOZ', 'TZA', 'ZMB']
# Borders:
# ['BRN', 'IDN', 'THA']
# Borders:
# []
# Borders:
# ['AGO', 'BWA', 'ZAF', 'ZMB']
# Borders:
# []
# Borders:
# ['DZA', 'BEN', 'BFA', 'TCD', 'LBY', 'MLI', 'NGA']
# Borders:
# []
# Borders:
# ['BEN', 'CMR', 'TCD', 'NER']
# Borders:
# ['CRI', 'HND']
# Borders:
# []
# Borders:
# ['BEL', 'DEU']
# Borders:
# ['FIN', 'SWE', 'RUS']
# Borders:
# ['CHN', 'IND']
# Borders:
# []
# Borders:
# []
# Borders:
# ['SAU', 'ARE', 'YEM']
# Borders:
# ['AFG', 'CHN', 'IND', 'IRN']
# Borders:
# ['COL', 'CRI']
# Borders:
# []
# Borders:
# ['BOL', 'BRA', 'CHL', 'COL', 'ECU']
# Borders:
# []
# Borders:
# []
# Borders:
# ['IDN']
# Borders:
# ['BLR', 'CZE', 'DEU', 'LTU', 'RUS', 'SVK', 'UKR']
# Borders:
# []
# Borders:
# ['CHN', 'KOR', 'RUS']
# Borders:
# ['ESP']
# Borders:
# ['ARG', 'BOL', 'BRA']
# Borders:
# ['ISR', 'EGY', 'JOR']
# Borders:
# []
# Borders:
# ['SAU']
# Borders:
# []
# Borders:
# ['BGR', 'HUN', 'MDA', 'SRB', 'UKR']
# Borders:
# ['AZE', 'BLR', 'CHN', 'EST', 'FIN', 'GEO', 'KAZ', 'PRK', 'LVA', 'LTU', 'MNG', 'NOR', 'POL', 'UKR']
# Borders:
# ['BDI', 'COD', 'TZA', 'UGA']
# Borders:
# ['IRQ', 'JOR', 'KWT', 'OMN', 'QAT', 'ARE', 'YEM']
# Borders:
# ['CAF', 'TCD', 'EGY', 'ERI', 'ETH', 'LBY', 'SSD']
# Borders:
# ['GMB', 'GIN', 'GNB', 'MLI', 'MRT']
# Borders:
# []
# Borders:
# []
# Borders:
# []
# Borders:
# []
# Borders:
# ['GIN', 'LBR']
# Borders:
# ['GTM', 'HND']
# Borders:
# ['ITA']
# Borders:
# ['DJI', 'ETH', 'KEN']
# Borders:
# []
# Borders:
# ['BIH', 'BGR', 'HRV', 'HUN', 'UNK', 'MKD', 'MNE', 'ROU']
# Borders:
# ['CAF', 'COD', 'ETH', 'KEN', 'SDN', 'UGA']
# Borders:
# []
# Borders:
# ['BRA', 'GUF', 'GUY']
# Borders:
# ['AUT', 'CZE', 'HUN', 'POL', 'UKR']
# Borders:
# ['AUT', 'HRV', 'ITA', 'HUN']
# Borders:
# ['FIN', 'NOR']
# Borders:
# ['MOZ', 'ZAF']
# Borders:
# ['MAF']
# Borders:
# []
# Borders:
# ['IRQ', 'ISR', 'JOR', 'LBN', 'TUR']
# Borders:
# []
# Borders:
# ['CMR', 'CAF', 'LBY', 'NER', 'NGA', 'SDN']
# Borders:
# ['BEN', 'BFA', 'GHA']
# Borders:
# ['MMR', 'KHM', 'LAO', 'MYS']
# Borders:
# ['AFG', 'CHN', 'KGZ', 'UZB']
# Borders:
# []
# Borders:
# ['AFG', 'IRN', 'KAZ', 'UZB']
# Borders:
# ['IDN']
# Borders:
# []
# Borders:
# []
# Borders:
# ['DZA', 'LBY']
# Borders:
# ['ARM', 'AZE', 'BGR', 'GEO', 'GRC', 'IRN', 'IRQ', 'SYR']
# Borders:
# []
# Borders:
# []
# Borders:
# ['BDI', 'COD', 'KEN', 'MWI', 'MOZ', 'RWA', 'UGA', 'ZMB']
# Borders:
# ['COD', 'KEN', 'RWA', 'SSD', 'TZA']
# Borders:
# ['BLR', 'HUN', 'MDA', 'POL', 'ROU', 'RUS', 'SVK']
# Borders:
# []
# Borders:
# ['ARG', 'BRA']
# Borders:
# ['CAN', 'MEX']
# Borders:
# ['AFG', 'KAZ', 'KGZ', 'TJK', 'TKM']
# Borders:
# ['ITA']
# Borders:
# []
# Borders:
# ['BRA', 'COL', 'GUY']
# Borders:
# []
# Borders:
# []
# Borders:
# ['KHM', 'CHN', 'LAO']
# Borders:
# []
# Borders:
# []
# Borders:
# []
# Borders:
# ['OMN', 'SAU']
# Borders:
# ['BWA', 'LSO', 'MOZ', 'NAM', 'SWZ', 'ZWE']
# Borders:
# ['AGO', 'BWA', 'COD', 'MWI', 'MOZ', 'NAM', 'TZA', 'ZWE']
# Borders:
# ['BWA', 'MOZ', 'ZAF', 'ZMB']

# %%
print(G.number_of_nodes())
print(G.number_of_edges())
# Out:
# 250
# 325

# %%
list(G.nodes)
# Out:
# ['Aruba',
#  'Afghanistan',
#  'Angola',
#  'Anguilla',
#  'Åland Islands',
#  'Albania',
#  'Andorra',
#  'United Arab Emirates',
#  'Argentina',
#  'Armenia',
#  'American Samoa',
#  'Antarctica',
#  'French Southern and Antarctic Lands',
#  'Antigua and Barbuda',
#  'Australia',
#  'Austria',
#  'Azerbaijan',
#  'Burundi',
#  'Belgium',
#  'Benin',
#  'Burkina Faso',
#  'Bangladesh',
#  'Bulgaria',
#  'Bahrain',
#  'Bahamas',
#  'Bosnia and Herzegovina',
#  'Saint Barthélemy',
#  'Saint Helena, Ascension and Tristan da Cunha',
#  'Belarus',
#  'Belize',
#  'Bermuda',
#  'Bolivia',
#  'Caribbean Netherlands',
#  'Brazil',
#  'Barbados',
#  'Brunei',
#  'Bhutan',
#  'Bouvet Island',
#  'Botswana',
#  'Central African Republic',
#  'Canada',
#  'Cocos (Keeling) Islands',
#  'Switzerland',
#  'Chile',
#  'China',
#  'Ivory Coast',
#  'Cameroon',
#  'DR Congo',
#  'Republic of the Congo',
#  'Cook Islands',
#  'Colombia',
#  'Comoros',
#  'Cape Verde',
#  'Costa Rica',
#  'Cuba',
#  'Curaçao',
#  'Christmas Island',
#  'Cayman Islands',
#  'Cyprus',
#  'Czechia',
#  'Germany',
#  'Djibouti',
#  'Dominica',
#  'Denmark',
#  'Dominican Republic',
#  'Algeria',
#  'Ecuador',
#  'Egypt',
#  'Eritrea',
#  'Western Sahara',
#  'Spain',
#  'Estonia',
#  'Ethiopia',
#  'Finland',
#  'Fiji',
#  'Falkland Islands',
#  'France',
#  'Faroe Islands',
#  'Micronesia',
#  'Gabon',
#  'United Kingdom',
#  'Georgia',
#  'Guernsey',
#  'Ghana',
#  'Gibraltar',
#  'Guinea',
#  'Guadeloupe',
#  'Gambia',
#  'Guinea-Bissau',
#  'Equatorial Guinea',
#  'Greece',
#  'Grenada',
#  'Greenland',
#  'Guatemala',
#  'French Guiana',
#  'Guam',
#  'Guyana',
#  'Hong Kong',
#  'Heard Island and McDonald Islands',
#  'Honduras',
#  'Croatia',
#  'Haiti',
#  'Hungary',
#  'Indonesia',
#  'Isle of Man',
#  'India',
#  'British Indian Ocean Territory',
#  'Ireland',
#  'Iran',
#  'Iraq',
#  'Iceland',
#  'Israel',
#  'Italy',
#  'Jamaica',
#  'Jersey',
#  'Jordan',
#  'Japan',
#  'Kazakhstan',
#  'Kenya',
#  'Kyrgyzstan',
#  'Cambodia',
#  'Kiribati',
#  'Saint Kitts and Nevis',
#  'South Korea',
#  'Kosovo',
#  'Kuwait',
#  'Laos',
#  'Lebanon',
#  'Liberia',
#  'Libya',
#  'Saint Lucia',
#  'Liechtenstein',
#  'Sri Lanka',
#  'Lesotho',
#  'Lithuania',
#  'Luxembourg',
#  'Latvia',
#  'Macau',
#  'Saint Martin',
#  'Morocco',
#  'Monaco',
#  'Moldova',
#  'Madagascar',
#  'Maldives',
#  'Mexico',
#  'Marshall Islands',
#  'North Macedonia',
#  'Mali',
#  'Malta',
#  'Myanmar',
#  'Montenegro',
#  'Mongolia',
#  'Northern Mariana Islands',
#  'Mozambique',
#  'Mauritania',
#  'Montserrat',
#  'Martinique',
#  'Mauritius',
#  'Malawi',
#  'Malaysia',
#  'Mayotte',
#  'Namibia',
#  'New Caledonia',
#  'Niger',
#  'Norfolk Island',
#  'Nigeria',
#  'Nicaragua',
#  'Niue',
#  'Netherlands',
#  'Norway',
#  'Nepal',
#  'Nauru',
#  'New Zealand',
#  'Oman',
#  'Pakistan',
#  'Panama',
#  'Pitcairn Islands',
#  'Peru',
#  'Philippines',
#  'Palau',
#  'Papua New Guinea',
#  'Poland',
#  'Puerto Rico',
#  'North Korea',
#  'Portugal',
#  'Paraguay',
#  'Palestine',
#  'French Polynesia',
#  'Qatar',
#  'Réunion',
#  'Romania',
#  'Russia',
#  'Rwanda',
#  'Saudi Arabia',
#  'Sudan',
#  'Senegal',
#  'Singapore',
#  'South Georgia',
#  'Svalbard and Jan Mayen',
#  'Solomon Islands',
#  'Sierra Leone',
#  'El Salvador',
#  'San Marino',
#  'Somalia',
#  'Saint Pierre and Miquelon',
#  'Serbia',
#  'South Sudan',
#  'São Tomé and Príncipe',
#  'Suriname',
#  'Slovakia',
#  'Slovenia',
#  'Sweden',
#  'Eswatini',
#  'Sint Maarten',
#  'Seychelles',
#  'Syria',
#  'Turks and Caicos Islands',
#  'Chad',
#  'Togo',
#  'Thailand',
#  'Tajikistan',
#  'Tokelau',
#  'Turkmenistan',
#  'Timor-Leste',
#  'Tonga',
#  'Trinidad and Tobago',
#  'Tunisia',
#  'Turkey',
#  'Tuvalu',
#  'Taiwan',
#  'Tanzania',
#  'Uganda',
#  'Ukraine',
#  'United States Minor Outlying Islands',
#  'Uruguay',
#  'United States',
#  'Uzbekistan',
#  'Vatican City',
#  'Saint Vincent and the Grenadines',
#  'Venezuela',
#  'British Virgin Islands',
#  'United States Virgin Islands',
#  'Vietnam',
#  'Vanuatu',
#  'Wallis and Futuna',
#  'Samoa',
#  'Yemen',
#  'South Africa',
#  'Zambia',
#  'Zimbabwe']

# %%
list(G.edges) #these are undirected edges
# Out:
# [('Afghanistan', 'Iran'),
#  ('Afghanistan', 'Pakistan'),
#  ('Afghanistan', 'Turkmenistan'),
#  ('Afghanistan', 'Uzbekistan'),
#  ('Afghanistan', 'Tajikistan'),
#  ('Afghanistan', 'China'),
#  ('Angola', 'Republic of the Congo'),
#  ('Angola', 'DR Congo'),
#  ('Angola', 'Zambia'),
#  ('Angola', 'Namibia'),
#  ('Albania', 'Montenegro'),
#  ('Albania', 'Greece'),
#  ('Albania', 'North Macedonia'),
#  ('Albania', 'Kosovo'),
#  ('Andorra', 'France'),
#  ('Andorra', 'Spain'),
#  ('United Arab Emirates', 'Oman'),
#  ('United Arab Emirates', 'Saudi Arabia'),
#  ('Argentina', 'Bolivia'),
#  ('Argentina', 'Brazil'),
#  ('Argentina', 'Chile'),
#  ('Argentina', 'Paraguay'),
#  ('Argentina', 'Uruguay'),
#  ('Armenia', 'Azerbaijan'),
#  ('Armenia', 'Georgia'),
#  ('Armenia', 'Iran'),
#  ('Armenia', 'Turkey'),
#  ('Austria', 'Czechia'),
#  ('Austria', 'Germany'),
#  ('Austria', 'Hungary'),
#  ('Austria', 'Italy'),
#  ('Austria', 'Liechtenstein'),
#  ('Austria', 'Slovakia'),
#  ('Austria', 'Slovenia'),
#  ('Austria', 'Switzerland'),
#  ('Azerbaijan', 'Georgia'),
#  ('Azerbaijan', 'Iran'),
#  ('Azerbaijan', 'Russia'),
#  ('Azerbaijan', 'Turkey'),
#  ('Burundi', 'DR Congo'),
#  ('Burundi', 'Rwanda'),
#  ('Burundi', 'Tanzania'),
#  ('Belgium', 'France'),
#  ('Belgium', 'Germany'),
#  ('Belgium', 'Luxembourg'),
#  ('Belgium', 'Netherlands'),
#  ('Benin', 'Burkina Faso'),
#  ('Benin', 'Niger'),
#  ('Benin', 'Nigeria'),
#  ('Benin', 'Togo'),
#  ('Burkina Faso', 'Ivory Coast'),
#  ('Burkina Faso', 'Ghana'),
#  ('Burkina Faso', 'Mali'),
#  ('Burkina Faso', 'Niger'),
#  ('Burkina Faso', 'Togo'),
#  ('Bangladesh', 'Myanmar'),
#  ('Bangladesh', 'India'),
#  ('Bulgaria', 'Greece'),
#  ('Bulgaria', 'North Macedonia'),
#  ('Bulgaria', 'Romania'),
#  ('Bulgaria', 'Serbia'),
#  ('Bulgaria', 'Turkey'),
#  ('Bosnia and Herzegovina', 'Croatia'),
#  ('Bosnia and Herzegovina', 'Montenegro'),
#  ('Bosnia and Herzegovina', 'Serbia'),
#  ('Belarus', 'Latvia'),
#  ('Belarus', 'Lithuania'),
#  ('Belarus', 'Poland'),
#  ('Belarus', 'Russia'),
#  ('Belarus', 'Ukraine'),
#  ('Belize', 'Guatemala'),
#  ('Belize', 'Mexico'),
#  ('Bolivia', 'Brazil'),
#  ('Bolivia', 'Chile'),
#  ('Bolivia', 'Paraguay'),
#  ('Bolivia', 'Peru'),
#  ('Brazil', 'Colombia'),
#  ('Brazil', 'French Guiana'),
#  ('Brazil', 'Guyana'),
#  ('Brazil', 'Paraguay'),
#  ('Brazil', 'Peru'),
#  ('Brazil', 'Suriname'),
#  ('Brazil', 'Uruguay'),
#  ('Brazil', 'Venezuela'),
#  ('Brunei', 'Malaysia'),
#  ('Bhutan', 'China'),
#  ('Bhutan', 'India'),
#  ('Botswana', 'Namibia'),
#  ('Botswana', 'South Africa'),
#  ('Botswana', 'Zambia'),
#  ('Botswana', 'Zimbabwe'),
#  ('Central African Republic', 'Cameroon'),
#  ('Central African Republic', 'Chad'),
#  ('Central African Republic', 'DR Congo'),
#  ('Central African Republic', 'Republic of the Congo'),
#  ('Central African Republic', 'South Sudan'),
#  ('Central African Republic', 'Sudan'),
#  ('Canada', 'United States'),
#  ('Switzerland', 'France'),
#  ('Switzerland', 'Italy'),
#  ('Switzerland', 'Liechtenstein'),
#  ('Switzerland', 'Germany'),
#  ('Chile', 'Peru'),
#  ('China', 'Myanmar'),
#  ('China', 'Hong Kong'),
#  ('China', 'India'),
#  ('China', 'Kazakhstan'),
#  ('China', 'Nepal'),
#  ('China', 'North Korea'),
#  ('China', 'Kyrgyzstan'),
#  ('China', 'Laos'),
#  ('China', 'Macau'),
#  ('China', 'Mongolia'),
#  ('China', 'Pakistan'),
#  ('China', 'Russia'),
#  ('China', 'Tajikistan'),
#  ('China', 'Vietnam'),
#  ('Ivory Coast', 'Ghana'),
#  ('Ivory Coast', 'Guinea'),
#  ('Ivory Coast', 'Liberia'),
#  ('Ivory Coast', 'Mali'),
#  ('Cameroon', 'Chad'),
#  ('Cameroon', 'Republic of the Congo'),
#  ('Cameroon', 'Equatorial Guinea'),
#  ('Cameroon', 'Gabon'),
#  ('Cameroon', 'Nigeria'),
#  ('DR Congo', 'Republic of the Congo'),
#  ('DR Congo', 'Rwanda'),
#  ('DR Congo', 'South Sudan'),
#  ('DR Congo', 'Tanzania'),
#  ('DR Congo', 'Uganda'),
#  ('DR Congo', 'Zambia'),
#  ('Republic of the Congo', 'Gabon'),
#  ('Colombia', 'Ecuador'),
#  ('Colombia', 'Panama'),
#  ('Colombia', 'Peru'),
#  ('Colombia', 'Venezuela'),
#  ('Costa Rica', 'Nicaragua'),
#  ('Costa Rica', 'Panama'),
#  ('Czechia', 'Germany'),
#  ('Czechia', 'Poland'),
#  ('Czechia', 'Slovakia'),
#  ('Germany', 'Denmark'),
#  ('Germany', 'France'),
#  ('Germany', 'Luxembourg'),
#  ('Germany', 'Netherlands'),
#  ('Germany', 'Poland'),
#  ('Djibouti', 'Eritrea'),
#  ('Djibouti', 'Ethiopia'),
#  ('Djibouti', 'Somalia'),
#  ('Dominican Republic', 'Haiti'),
#  ('Algeria', 'Tunisia'),
#  ('Algeria', 'Libya'),
#  ('Algeria', 'Niger'),
#  ('Algeria', 'Western Sahara'),
#  ('Algeria', 'Mauritania'),
#  ('Algeria', 'Mali'),
#  ('Algeria', 'Morocco'),
#  ('Ecuador', 'Peru'),
#  ('Egypt', 'Israel'),
#  ('Egypt', 'Libya'),
#  ('Egypt', 'Palestine'),
#  ('Egypt', 'Sudan'),
#  ('Eritrea', 'Ethiopia'),
#  ('Eritrea', 'Sudan'),
#  ('Western Sahara', 'Mauritania'),
#  ('Western Sahara', 'Morocco'),
#  ('Spain', 'France'),
#  ('Spain', 'Gibraltar'),
#  ('Spain', 'Portugal'),
#  ('Spain', 'Morocco'),
#  ('Estonia', 'Latvia'),
#  ('Estonia', 'Russia'),
#  ('Ethiopia', 'Kenya'),
#  ('Ethiopia', 'Somalia'),
#  ('Ethiopia', 'South Sudan'),
#  ('Ethiopia', 'Sudan'),
#  ('Finland', 'Norway'),
#  ('Finland', 'Sweden'),
#  ('Finland', 'Russia'),
#  ('France', 'Italy'),
#  ('France', 'Luxembourg'),
#  ('France', 'Monaco'),
#  ('Gabon', 'Equatorial Guinea'),
#  ('United Kingdom', 'Ireland'),
#  ('Georgia', 'Russia'),
#  ('Georgia', 'Turkey'),
#  ('Ghana', 'Togo'),
#  ('Guinea', 'Guinea-Bissau'),
#  ('Guinea', 'Liberia'),
#  ('Guinea', 'Mali'),
#  ('Guinea', 'Senegal'),
#  ('Guinea', 'Sierra Leone'),
#  ('Gambia', 'Senegal'),
#  ('Guinea-Bissau', 'Senegal'),
#  ('Greece', 'Turkey'),
#  ('Greece', 'North Macedonia'),
#  ('Guatemala', 'El Salvador'),
#  ('Guatemala', 'Honduras'),
#  ('Guatemala', 'Mexico'),
#  ('French Guiana', 'Suriname'),
#  ('Guyana', 'Suriname'),
#  ('Guyana', 'Venezuela'),
#  ('Honduras', 'El Salvador'),
#  ('Honduras', 'Nicaragua'),
#  ('Croatia', 'Hungary'),
#  ('Croatia', 'Montenegro'),
#  ('Croatia', 'Serbia'),
#  ('Croatia', 'Slovenia'),
#  ('Hungary', 'Romania'),
#  ('Hungary', 'Serbia'),
#  ('Hungary', 'Slovakia'),
#  ('Hungary', 'Slovenia'),
#  ('Hungary', 'Ukraine'),
#  ('Indonesia', 'Timor-Leste'),
#  ('Indonesia', 'Malaysia'),
#  ('Indonesia', 'Papua New Guinea'),
#  ('India', 'Myanmar'),
#  ('India', 'Nepal'),
#  ('India', 'Pakistan'),
#  ('India', 'Sri Lanka'),
#  ('Iran', 'Iraq'),
#  ('Iran', 'Pakistan'),
#  ('Iran', 'Turkey'),
#  ('Iran', 'Turkmenistan'),
#  ('Iraq', 'Jordan'),
#  ('Iraq', 'Kuwait'),
#  ('Iraq', 'Saudi Arabia'),
#  ('Iraq', 'Syria'),
#  ('Iraq', 'Turkey'),
#  ('Israel', 'Jordan'),
#  ('Israel', 'Lebanon'),
#  ('Israel', 'Palestine'),
#  ('Israel', 'Syria'),
#  ('Italy', 'San Marino'),
#  ('Italy', 'Slovenia'),
#  ('Italy', 'Vatican City'),
#  ('Jordan', 'Palestine'),
#  ('Jordan', 'Saudi Arabia'),
#  ('Jordan', 'Syria'),
#  ('Kazakhstan', 'Kyrgyzstan'),
#  ('Kazakhstan', 'Russia'),
#  ('Kazakhstan', 'Turkmenistan'),
#  ('Kazakhstan', 'Uzbekistan'),
#  ('Kenya', 'Somalia'),
#  ('Kenya', 'South Sudan'),
#  ('Kenya', 'Tanzania'),
#  ('Kenya', 'Uganda'),
#  ('Kyrgyzstan', 'Tajikistan'),
#  ('Kyrgyzstan', 'Uzbekistan'),
#  ('Cambodia', 'Laos'),
#  ('Cambodia', 'Thailand'),
#  ('Cambodia', 'Vietnam'),
#  ('South Korea', 'North Korea'),
#  ('Kosovo', 'North Macedonia'),
#  ('Kosovo', 'Montenegro'),
#  ('Kosovo', 'Serbia'),
#  ('Kuwait', 'Saudi Arabia'),
#  ('Laos', 'Myanmar'),
#  ('Laos', 'Thailand'),
#  ('Laos', 'Vietnam'),
#  ('Lebanon', 'Syria'),
#  ('Liberia', 'Sierra Leone'),
#  ('Libya', 'Chad'),
#  ('Libya', 'Niger'),
#  ('Libya', 'Sudan'),
#  ('Libya', 'Tunisia'),
#  ('Lesotho', 'South Africa'),
#  ('Lithuania', 'Latvia'),
#  ('Lithuania', 'Poland'),
#  ('Lithuania', 'Russia'),
#  ('Latvia', 'Russia'),
#  ('Saint Martin', 'Sint Maarten'),
#  ('Moldova', 'Romania'),
#  ('Moldova', 'Ukraine'),
#  ('Mexico', 'United States'),
#  ('North Macedonia', 'Serbia'),
#  ('Mali', 'Mauritania'),
#  ('Mali', 'Niger'),
#  ('Mali', 'Senegal'),
#  ('Myanmar', 'Thailand'),
#  ('Montenegro', 'Serbia'),
#  ('Mongolia', 'Russia'),
#  ('Mozambique', 'Malawi'),
#  ('Mozambique', 'South Africa'),
#  ('Mozambique', 'Eswatini'),
#  ('Mozambique', 'Tanzania'),
#  ('Mozambique', 'Zambia'),
#  ('Mozambique', 'Zimbabwe'),
#  ('Mauritania', 'Senegal'),
#  ('Malawi', 'Tanzania'),
#  ('Malawi', 'Zambia'),
#  ('Malaysia', 'Thailand'),
#  ('Namibia', 'South Africa'),
#  ('Namibia', 'Zambia'),
#  ('Niger', 'Chad'),
#  ('Niger', 'Nigeria'),
#  ('Nigeria', 'Chad'),
#  ('Norway', 'Sweden'),
#  ('Norway', 'Russia'),
#  ('Oman', 'Saudi Arabia'),
#  ('Oman', 'Yemen'),
#  ('Poland', 'Russia'),
#  ('Poland', 'Slovakia'),
#  ('Poland', 'Ukraine'),
#  ('North Korea', 'Russia'),
#  ('Qatar', 'Saudi Arabia'),
#  ('Romania', 'Serbia'),
#  ('Romania', 'Ukraine'),
#  ('Russia', 'Ukraine'),
#  ('Rwanda', 'Tanzania'),
#  ('Rwanda', 'Uganda'),
#  ('Saudi Arabia', 'Yemen'),
#  ('Sudan', 'Chad'),
#  ('Sudan', 'South Sudan'),
#  ('South Sudan', 'Uganda'),
#  ('Slovakia', 'Ukraine'),
#  ('Eswatini', 'South Africa'),
#  ('Syria', 'Turkey'),
#  ('Tajikistan', 'Uzbekistan'),
#  ('Turkmenistan', 'Uzbekistan'),
#  ('Tanzania', 'Uganda'),
#  ('Tanzania', 'Zambia'),
#  ('South Africa', 'Zimbabwe'),
#  ('Zambia', 'Zimbabwe')]

# %%
#want to find shortest paths between our 20 countries
countries = ["Australia", "Brazil", "Canada", "Colombia", "Costa Rica", "France", "Germany", "Guatemala", "Hong Kong",
            "India", "Japan", "Mexico", "Netherlands", "New Zealand", "Philippines", "Singapore", "Sweden", "Turkey", "United Kingdom", "United States"];

allshortestpaths = nx.shortest_path(G)

# %%
allshortestpathsdict = {}

for x in countries:
    countryshortestpathsdict = {}
    for y in countries:
        if x != y and y in allshortestpaths[x].keys():
            #print(x)
            #print(y)
            #print(allshortestpaths[x][y])
            countryshortestpathsdict[y] = allshortestpaths[x][y]
    allshortestpathsdict[x] = countryshortestpathsdict

allshortestpathsdict
# Out:
# {'Australia': {},
#  'Brazil': {'Canada': ['Brazil',
#    'Colombia',
#    'Panama',
#    'Costa Rica',
#    'Nicaragua',
#    'Honduras',
#    'Guatemala',
#    'Mexico',
#    'United States',
#    'Canada'],
#   'Colombia': ['Brazil', 'Colombia'],
#   'Costa Rica': ['Brazil', 'Colombia', 'Panama', 'Costa Rica'],
#   'Guatemala': ['Brazil',
#    'Colombia',
#    'Panama',
#    'Costa Rica',
#    'Nicaragua',
#    'Honduras',
#    'Guatemala'],
#   'Mexico': ['Brazil',
#    'Colombia',
#    'Panama',
#    'Costa Rica',
#    'Nicaragua',
#    'Honduras',
#    'Guatemala',
#    'Mexico'],
#   'United States': ['Brazil',
#    'Colombia',
#    'Panama',
#    'Costa Rica',
#    'Nicaragua',
#    'Honduras',
#    'Guatemala',
#    'Mexico',
#    'United States']},
#  'Canada': {'Brazil': ['Canada',
#    'United States',
#    'Mexico',
#    'Guatemala',
#    'Honduras',
#    'Nicaragua',
#    'Costa Rica',
#    'Panama',
#    'Colombia',
#    'Brazil'],
#   'Colombia': ['Canada',
#    'United States',
#    'Mexico',
#    'Guatemala',
#    'Honduras',
#    'Nicaragua',
#    'Costa Rica',
#    'Panama',
#    'Colombia'],
#   'Costa Rica': ['Canada',
#    'United States',
#    'Mexico',
#    'Guatemala',
#    'Honduras',
#    'Nicaragua',
#    'Costa Rica'],
#   'Guatemala': ['Canada', 'United States', 'Mexico', 'Guatemala'],
#   'Mexico': ['Canada', 'United States', 'Mexico'],
#   'United States': ['Canada', 'United States']},
#  'Colombia': {'Brazil': ['Colombia', 'Brazil'],
#   'Canada': ['Colombia',
#    'Panama',
#    'Costa Rica',
#    'Nicaragua',
#    'Honduras',
#    'Guatemala',
#    'Mexico',
#    'United States',
#    'Canada'],
#   'Costa Rica': ['Colombia', 'Panama', 'Costa Rica'],
#   'Guatemala': ['Colombia',
#    'Panama',
#    'Costa Rica',
#    'Nicaragua',
#    'Honduras',
#    'Guatemala'],
#   'Mexico': ['Colombia',
#    'Panama',
#    'Costa Rica',
#    'Nicaragua',
#    'Honduras',
#    'Guatemala',
#    'Mexico'],
#   'United States': ['Colombia',
#    'Panama',
#    'Costa Rica',
#    'Nicaragua',
#    'Honduras',
#    'Guatemala',
#    'Mexico',
#    'United States']},
#  'Costa Rica': {'Brazil': ['Costa Rica', 'Panama', 'Colombia', 'Brazil'],
#   'Canada': ['Costa Rica',
#    'Nicaragua',
#    'Honduras',
#    'Guatemala',
#    'Mexico',
#    'United States',
#    'Canada'],
#   'Colombia': ['Costa Rica', 'Panama', 'Colombia'],
#   'Guatemala': ['Costa Rica', 'Nicaragua', 'Honduras', 'Guatemala'],
#   'Mexico': ['Costa Rica', 'Nicaragua', 'Honduras', 'Guatemala', 'Mexico'],
#   'United States': ['Costa Rica',
#    'Nicaragua',
#    'Honduras',
#    'Guatemala',
#    'Mexico',
#    'United States']},
#  'France': {'Germany': ['France', 'Germany'],
#   'Hong Kong': ['France', 'Germany', 'Poland', 'Russia', 'China', 'Hong Kong'],
#   'India': ['France', 'Germany', 'Poland', 'Russia', 'China', 'India'],
#   'Netherlands': ['France', 'Belgium', 'Netherlands'],
#   'Sweden': ['France', 'Germany', 'Poland', 'Russia', 'Finland', 'Sweden'],
#   'Turkey': ['France', 'Germany', 'Poland', 'Russia', 'Azerbaijan', 'Turkey']},
#  'Germany': {'France': ['Germany', 'France'],
#   'Hong Kong': ['Germany', 'Poland', 'Russia', 'China', 'Hong Kong'],
#   'India': ['Germany', 'Poland', 'Russia', 'China', 'India'],
#   'Netherlands': ['Germany', 'Netherlands'],
#   'Sweden': ['Germany', 'Poland', 'Russia', 'Finland', 'Sweden'],
#   'Turkey': ['Germany', 'Poland', 'Russia', 'Azerbaijan', 'Turkey']},
#  'Guatemala': {'Brazil': ['Guatemala',
#    'Honduras',
#    'Nicaragua',
#    'Costa Rica',
#    'Panama',
#    'Colombia',
#    'Brazil'],
#   'Canada': ['Guatemala', 'Mexico', 'United States', 'Canada'],
#   'Colombia': ['Guatemala',
#    'Honduras',
#    'Nicaragua',
#    'Costa Rica',
#    'Panama',
#    'Colombia'],
#   'Costa Rica': ['Guatemala', 'Honduras', 'Nicaragua', 'Costa Rica'],
#   'Mexico': ['Guatemala', 'Mexico'],
#   'United States': ['Guatemala', 'Mexico', 'United States']},
#  'Hong Kong': {'France': ['Hong Kong',
#    'China',
#    'Russia',
#    'Poland',
#    'Germany',
#    'France'],
#   'Germany': ['Hong Kong', 'China', 'Russia', 'Poland', 'Germany'],
#   'India': ['Hong Kong', 'China', 'India'],
#   'Netherlands': ['Hong Kong',
#    'China',
#    'Russia',
#    'Poland',
#    'Germany',
#    'Netherlands'],
#   'Sweden': ['Hong Kong', 'China', 'Russia', 'Finland', 'Sweden'],
#   'Turkey': ['Hong Kong', 'China', 'Afghanistan', 'Iran', 'Turkey']},
#  'India': {'France': ['India',
#    'China',
#    'Russia',
#    'Poland',
#    'Germany',
#    'France'],
#   'Germany': ['India', 'China', 'Russia', 'Poland', 'Germany'],
#   'Hong Kong': ['India', 'China', 'Hong Kong'],
#   'Netherlands': ['India',
#    'China',
#    'Russia',
#    'Poland',
#    'Germany',
#    'Netherlands'],
#   'Sweden': ['India', 'China', 'Russia', 'Finland', 'Sweden'],
#   'Turkey': ['India', 'Pakistan', 'Iran', 'Turkey']},
#  'Japan': {},
#  'Mexico': {'Brazil': ['Mexico',
#    'Guatemala',
#    'Honduras',
#    'Nicaragua',
#    'Costa Rica',
#    'Panama',
#    'Colombia',
#    'Brazil'],
#   'Canada': ['Mexico', 'United States', 'Canada'],
#   'Colombia': ['Mexico',
#    'Guatemala',
#    'Honduras',
#    'Nicaragua',
#    'Costa Rica',
#    'Panama',
#    'Colombia'],
#   'Costa Rica': ['Mexico', 'Guatemala', 'Honduras', 'Nicaragua', 'Costa Rica'],
#   'Guatemala': ['Mexico', 'Guatemala'],
#   'United States': ['Mexico', 'United States']},
#  'Netherlands': {'France': ['Netherlands', 'Belgium', 'France'],
#   'Germany': ['Netherlands', 'Germany'],
#   'Hong Kong': ['Netherlands',
#    'Germany',
#    'Poland',
#    'Russia',
#    'China',
#    'Hong Kong'],
#   'India': ['Netherlands', 'Germany', 'Poland', 'Russia', 'China', 'India'],
#   'Sweden': ['Netherlands',
#    'Germany',
#    'Poland',
#    'Russia',
#    'Finland',
#    'Sweden'],
#   'Turkey': ['Netherlands',
#    'Germany',
#    'Poland',
#    'Russia',
#    'Azerbaijan',
#    'Turkey']},
#  'New Zealand': {},
#  'Philippines': {},
#  'Singapore': {},
#  'Sweden': {'France': ['Sweden',
#    'Finland',
#    'Russia',
#    'Poland',
#    'Germany',
#    'France'],
#   'Germany': ['Sweden', 'Finland', 'Russia', 'Poland', 'Germany'],
#   'Hong Kong': ['Sweden', 'Finland', 'Russia', 'China', 'Hong Kong'],
#   'India': ['Sweden', 'Finland', 'Russia', 'China', 'India'],
#   'Netherlands': ['Sweden',
#    'Finland',
#    'Russia',
#    'Poland',
#    'Germany',
#    'Netherlands'],
#   'Turkey': ['Sweden', 'Finland', 'Russia', 'Azerbaijan', 'Turkey']},
#  'Turkey': {'France': ['Turkey',
#    'Azerbaijan',
#    'Russia',
#    'Poland',
#    'Germany',
#    'France'],
#   'Germany': ['Turkey', 'Azerbaijan', 'Russia', 'Poland', 'Germany'],
#   'Hong Kong': ['Turkey', 'Azerbaijan', 'Russia', 'China', 'Hong Kong'],
#   'India': ['Turkey', 'Iran', 'Pakistan', 'India'],
#   'Netherlands': ['Turkey',
#    'Azerbaijan',
#    'Russia',
#    'Poland',
#    'Germany',
#    'Netherlands'],
#   'Sweden': ['Turkey', 'Azerbaijan', 'Russia', 'Finland', 'Sweden']},
#  'United Kingdom': {},
#  'United States': {'Brazil': ['United States',
#    'Mexico',
#    'Guatemala',
#    'Honduras',
#    'Nicaragua',
#    'Costa Rica',
#    'Panama',
#    'Colombia',
#    'Brazil'],
#   'Canada': ['United States', 'Canada'],
#   'Colombia': ['United States',
#    'Mexico',
#    'Guatemala',
#    'Honduras',
#    'Nicaragua',
#    'Costa Rica',
#    'Panama',
#    'Colombia'],
#   'Costa Rica': ['United States',
#    'Mexico',
#    'Guatemala',
#    'Honduras',
#    'Nicaragua',
#    'Costa Rica'],
#   'Guatemala': ['United States', 'Mexico', 'Guatemala'],
#   'Mexico': ['United States', 'Mexico']}}
