# %%
# !pip install lyricsgenius
# !pip install langdetect
# !pip install pandas
# Out:
# ...
#      |████████████████████████████████| 15.9MB 5.9MB/s eta 0:00:01     |██████████████████████████████▌ | 15.2MB 5.9MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 13.9MB 14.3MB/s eta 0:00:01
# ...
#   Using cached https://files.pythonhosted.org/packages/3d/73/fe30c2daaaa0713420d0382b16fbb761409f532c56bdcc514bf7b6262bb6/pytz-2019.1-py2.py3-none-any.whl
# ...

# %%
import lyricsgenius
from langdetect import detect
import pandas as pd
import numpy as np

genius = lyricsgenius.Genius("dBNV46R1h2UMxXgLEJPtIwm0_WlVKKJ1TrVu7eYlr-pdv_kikEPRAmdJPv-gkIIY")
#artist = genius.search_artist("Andy Shauf", max_songs=3, sort="title")
#print(artist.songs)

# %%
data_aus = pd.read_csv("Australia.csv", header=1)
data_brz = pd.read_csv("Brazil.csv", header=1)
data_can = pd.read_csv("Canada.csv", header=1)
data_col = pd.read_csv("Colombia.csv", header=1)
data_cor = pd.read_csv("Costa_Rica.csv", header=1)
data_fra = pd.read_csv("France.csv", header=1)
data_ger = pd.read_csv("Germany.csv", header=1)
data_gua = pd.read_csv("Guatemala.csv", header=1)
data_hk = pd.read_csv("HK.csv", header=1)
data_ind = pd.read_csv("India.csv", header=1)
data_jap = pd.read_csv("Japan.csv", header=1)
data_mex = pd.read_csv("Mexico.csv", header=1)
data_neth = pd.read_csv("Netherlands.csv", header=1)
data_nz = pd.read_csv("NZ.csv", header=1)
data_phi = pd.read_csv("Philipines.csv", header=1)
data_sng = pd.read_csv("Singapore.csv", header=1)
data_swe = pd.read_csv("Sweden.csv", header=1)
data_tur = pd.read_csv("Turkey.csv", header=1)
data_uk = pd.read_csv("UK.csv", header=1)
data_us = pd.read_csv("US.csv", header=1)

# %%
list_of_data_files = [data_aus, data_brz, data_can, data_col, data_cor, data_fra, data_ger, 
                      data_gua, data_hk, data_ind, data_jap, data_mex, data_neth, data_nz, 
                      data_phi, data_phi, data_sng, data_swe, data_tur, data_uk, data_us]
list_of_text_files = ["Australia_lyrics.txt", "Brazil_lyrics.txt", "Canada_lyrics.txt", "Colombia_lyrics.txt", "Costa_Rica_lyrics.txt", "France_lyrics.txt", "Germany_lyrics.txt", "Guatemala_lyrics.txt", "Hong_Kong_lyrics.txt",
            "India_lyrics.txt", "Japan_lyrics.txt", "Mexico_lyrics.txt", "Netherlands_lyrics.txt", "New_Zealand_lyrics.txt", "Philippines_lyrics.txt", "Singapore_lyrics.txt", "Sweden_lyrics.txt", "Turkey_lyrics.txt", "United_Kingdom_lyrics.txt", "United_States_lyrics.txt"];

for data_file_index in range(len(list_of_data_files)):
    data_file = list_of_data_files[data_file_index]
    text_file = list_of_text_files[data_file_index]
    f = open(text_file, "w+")
    counter = 0
    for index, row in data_file.iterrows():
        if counter >= 50:
            break
        #if (row['Track Name'] === "Outta My Head (with John Mayer)"):
        #    row['Track Name'] = "Outta My Head"
            
        if ("(with" in row['Track Name']):
            #print(row['Track Name'])
            row['Track Name'] = row['Track Name'].split("(with",1)[0] 
        song = genius.search_song(row['Track Name'], row['Artist'])
        #print(type(song))
        if (song != None):
            if(detect(song.lyrics) == 'en'):
                #print(song.lyrics)
                #append to some document
                f.write(song.lyrics + "\n")
        counter = counter + 1
    f.close()

# %%
#data_us.head()
data_us = data_us[['Track Name', 'Artist']]
data_us.head()
for index, row in data_us.iterrows():
    
    song = genius.search_song(row['Track Name'], row['Artist'])
    if(detect(song.lyrics) == 'en'):
        print(song.lyrics)
        #append to some document
        break
    else:
        print("NOT ENGLISH")
    break
    #print(row['Track Name'], row['Artist'])

# %%
song = genius.search_song("Keisha & Becky - Remix")
print(song)
# Out:
# Searching for "Keisha & Becky - Remix"...
# Done.
# "Keisha & Becky Remix" by Russ (MSplash):
#     [Intro: Russ & Tion Wayne]
#     Very sexy, Keisha, Becky
#     Mhm-mhm, mhm-mhm, mhm-mhm
#
#     [Chorus: Tion Wayne &...

# %%
list_of_data_files = [data_uk]
list_of_text_files = ["United_Kingdom_lyrics.txt"];

for data_file_index in range(len(list_of_data_files)):
    data_file = list_of_data_files[data_file_index]
    text_file = list_of_text_files[data_file_index]
    f = open(text_file, "w+")
    counter = 0
    for index, row in data_file.iterrows():
        if counter >= 50:
            break
        #if (row['Track Name'] === "Outta My Head (with John Mayer)"):
        #    row['Track Name'] = "Outta My Head"
            
        if ("(with" in row['Track Name']):
            #print(row['Track Name'])
            row['Track Name'] = row['Track Name'].split("(with",1)[0] 
        if (row['Track Name'] == "Keisha & Becky - Remix"):
            song = genius.search_song(row['Track Name'])
        else:
            song = genius.search_song(row['Track Name'], row['Artist'])
        print(type(song))
        if (song != None):
            if(detect(song.lyrics) == 'en'):
                print(song.lyrics)
                #append to some document
                f.write(song.lyrics + "\n")
        counter = counter + 1
    f.close()
# Out:
# Searching for "bad guy" by Billie Eilish...
# Done.
# <class 'lyricsgenius.song.Song'>
# [Verse 1]
# White shirt now red, my bloody nose
# Sleepin', you're on your tippy toes
# Creepin' around like no one knows
# Think you're so criminal
# Bruises on both my knees for you
# Don't say thank you or please
# I do what I want when I'm wanting to
# My soul? So cynical
#
# [Chorus]
# So you're a tough guy
# Like it really rough guy
# Just can't get enough guy
# Chest always so puffed guy
# I'm that bad type
# Make your mama sad type
# Make your girlfriend mad tight
# Might seduce your dad type
# I'm the bad guy
# Duh
#
# [Post-Chorus]
# I'm the bad guy
#
# [Verse 2]
# I like it when you take control
# Even if you know that you don't
# Own me, I'll let you play the role
# I'll be your animal
# My mommy likes to sing along with me
# But she won't sing this song
# If she reads all the lyrics
# She'll pity the men I know
#
# [Chorus]
# So you're a tough guy
# Like it really rough guy
# ...

# %%
cosSim = pd.read_csv("normalizedCosSimilarity.csv") 
cosSim.head()
# Out:
#        Country 1       Country 2  Normalized
# 0      Singapore     Philippines      5.2953
# 1  United States  United Kingdom      4.9758
# 2      Guatemala          Mexico      4.1762
# 3      Australia     New Zealand      3.0932
# 4      Australia       Hong Kong      2.3335

# %%
#create a graph with edges for normalized > 0

import networkx as nx

G = nx.Graph()

countries = ["Australia", "Brazil", "Canada", "Colombia", "Costa Rica", "France", "Germany", "Guatemala", "Hong Kong",
            "India", "Japan", "Mexico", "Netherlands", "New Zealand", "Philippines", "Singapore", "Sweden", "Turkey", "United Kingdom", "United States"];


for n in countries:
    G.add_node(n)

for idx, row in cosSim.iterrows():
    if (row[0] in countries and row[1] in countries and row[2] > 0):
        G.add_edge(row[0], row[1])

# %%
import matplotlib.pyplot as plt
#!pip install scipy
from scipy.optimize import minimize

nx.draw_circular(G, with_labels=True, font_size=12, node_size=150)

axes = plt.gca()
axes.set_xlim([-1.2, 1.3])
axes.set_ylim([-1.2, 1.2])
plt.axis('off')
plt.rcParams['figure.figsize'] = [10, 10]

#edge_labels = nx.draw_networkx_edge_labels(Gsmall, pos=nx.shell_layout(Gsmall, nlist=[['Brazil', 'Canada', 'Colombia', 'Costa Rica', 'Guatemala', 'Mexico', 'United States'], ['France', 'Germany', 'Hong Kong', 'India', 'Netherlands', 'Sweden', 'Turkey'], ["Australia", "Philippines", "Singapore", "Japan", "United Kingdom", "New Zealand"]]))

#nx.draw_networkx_edge_labels(Gsmall, edge_labels)
#plt.savefig("test.png") # save as png
plt.show()

# %%
##### COMPARISON WITH FLIGHT DATA #####

# %%
routes = pd.read_csv('routes.txt', sep=",", header=None)
airports = pd.read_csv('airportsInfo.txt', sep=",", header=None)

routes.columns = ["Airline", "Airline_ID", "Source_Airport", "Source_Airport_ID", "Dest_Airport", "Dest_Airport_ID", "Codeshare", "Stops", "Equipment"]
routes = routes.drop(["Airline", "Airline_ID", "Source_Airport_ID", "Dest_Airport_ID", "Codeshare", "Stops", "Equipment"], axis=1)

airports.columns = ["Airport_ID", "Name", "City", "Country", "IATA", "ICAO", "Lat", "Long", "Alt", "Timezone", "DST", "Tz", "Type", "Source"]
airports = airports.drop(["Airport_ID", "Name", "City", "ICAO", "Lat", "Long", "Alt", "Timezone", "DST", "Tz", "Type", "Source"], axis=1)

airports.head()
#routes.head()

merge1 = pd.merge(routes, airports, how='inner', on=None, left_on='Source_Airport', right_on='IATA',
         left_index=False, right_index=False, sort=True,
         suffixes=('_x', '_y'), copy=True, indicator=False,
         validate=None)
merge1.columns = ["Source_Airport", "Dest_Airport", "Source_Country", "Source_IATA"]

merge2 = pd.merge(merge1, airports, how='inner', on=None, left_on='Dest_Airport', right_on='IATA',
         left_index=False, right_index=False, sort=True,
         suffixes=('_x', '_y'), copy=True, indicator=False,
         validate=None)
merge2.columns = ["Source_Airport", "Dest_Airport", "Source_Country", "Source_IATA", "Dest_Country", "Dest_IATA"]

flights = merge2.drop(["Source_Airport", "Dest_Airport", "Source_IATA", "Dest_IATA"], axis=1)

flights.head()
# Out:
#   Source_Country Dest_Country
# 0        Algeria      Algeria
# 1         France      Algeria
# 2         Turkey      Algeria
# 3         France      Algeria
# 4         France      Algeria

# %%
countries = ["Australia", "Brazil", "Canada", "Colombia", "Costa Rica", "France", "Germany", "Guatemala", "Hong Kong",
            "India", "Japan", "Mexico", "Netherlands", "New Zealand", "Philippines", "Singapore", "Sweden", "Turkey", "United Kingdom", "United States"];

# %%
Gflights = nx.Graph()

for n in countries:
    Gflights.add_node(n)

for idx, row in flights.iterrows():
    if (row[0] in countries and row[1] in countries):
        Gflights.add_edge(row[0], row[1])

# %%
GflightIntersect = nx.intersection(Gflights, G)

nx.draw_circular(GflightIntersect, with_labels=True, font_size=12, node_size=150)

axes = plt.gca()
axes.set_xlim([-1.2, 1.3])
axes.set_ylim([-1.2, 1.2])
plt.axis('off')
plt.rcParams['figure.figsize'] = [10, 10]

#edge_labels = nx.draw_networkx_edge_labels(Gsmall, pos=nx.shell_layout(Gsmall, nlist=[['Brazil', 'Canada', 'Colombia', 'Costa Rica', 'Guatemala', 'Mexico', 'United States'], ['France', 'Germany', 'Hong Kong', 'India', 'Netherlands', 'Sweden', 'Turkey'], ["Australia", "Philippines", "Singapore", "Japan", "United Kingdom", "New Zealand"]]))

#nx.draw_networkx_edge_labels(Gsmall, edge_labels)
#plt.savefig("test.png") # save as png
plt.show()

# %%
len(GflightIntersect.edges)/len(G.edges)
# Out:
# 0.3870967741935484

# %%
##### COMPARISON WITH TRADE DATA #####

# %%
Gtrade = nx.Graph()
trade = pd.read_csv("tradeFilteredExpanded.csv") 
trade.head()

nodearr = pd.unique(trade[['Country 1', 'Country 2']].values.ravel('K'))
for n in nodearr:
    Gtrade.add_node(n)

for idx, row in trade.iterrows():
    Gtrade.add_edge(row[0], row[1])

# %%
countrydiff = np.setdiff1d(np.array(countries), nodearr)
countrydiff = list(countrydiff)
print(Gtrade.nodes)
countrydiff
# Out:
# ['Colombia', 'Singapore', 'Australia', 'New Zealand', 'Japan', 'Philippines', 'United States', 'Canada', 'Brazil', 'Mexico', 'India']
# ['Costa Rica',
#  'France',
#  'Germany',
#  'Guatemala',
#  'Hong Kong',
#  'Netherlands',
#  'Sweden',
#  'Turkey',
#  'United Kingdom']

# %%
Gnodesremoved = G
for node in countrydiff:
    Gnodesremoved.remove_node(node)

# %%
nx.draw_circular(Gtrade, with_labels=True, font_size=12, node_size=150)
axes = plt.gca()
axes.set_xlim([-1.3, 1.3])
axes.set_ylim([-1.2, 1.2])
plt.axis('off')
plt.rcParams['figure.figsize'] = [5, 5]

plt.show()

# %%
GtradeIntersect = nx.intersection(Gtrade, Gnodesremoved)

nx.draw_circular(GtradeIntersect, with_labels=True, font_size=12, node_size=150)

axes = plt.gca()
axes.set_xlim([-1.3, 1.3])
axes.set_ylim([-1.2, 1.2])
plt.axis('off')
plt.rcParams['figure.figsize'] = [5, 5]

plt.show()

# %%
len(GtradeIntersect.edges)/len(Gnodesremoved.edges)
# Out:
# 0.9565217391304348

# %%
nx.draw_circular(Gnodesremoved, with_labels=True, font_size=12, node_size=150)

axes = plt.gca()
axes.set_xlim([-1.3, 1.3])
axes.set_ylim([-1.2, 1.2])
plt.axis('off')
plt.rcParams['figure.figsize'] = [5, 5]

plt.show()
